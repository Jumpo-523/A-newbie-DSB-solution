# %%
import pandas as pd, seaborn as sns, numpy as np

# %%
imps = pd.read_csv("../data-science-bowl-2019/features/importance.csv")

# %%
imps
# Out:
#                                       name  importance
# 0                                        0        14.8
# 1                                        1        10.4
# 2                               12_Monkeys         7.8
# 3                          12_Monkeys_2000         0.0
# 4                                        2         4.6
# ...                                    ...         ...
# 9915               score_title_Scrub-A-Dub         0.0
# 9916  score_title_Watering_Hole_(Activity)         0.0
# 9917                         session_title       125.4
# 9918                                  size        59.4
# 9919                                weight        54.8
#
# [9920 rows x 2 columns]

# %%
# top_features = imp_total.groupby("feature").agg({"importance": ["mean", "std"]}).sort_values(("importance", "mean"), ascending=False).iloc[0:100].index.to_list()
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
def watch_all_featuresImp(imps, top_features=None):
    fig, ax = plt.subplots(figsize=(10, 100))
    sns.barplot(data=imps, x='importance', y='name', orient='h', ax=ax, order=top_features)
watch_all_featuresImp(imps)

# %%
import datetime

# %%
# Out:
# '20200102_1844'

# %%
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold

# %%
# StratifiedKFold

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-ddea2f941dcb> in <module>
# ----> 1 import spark
#
# ModuleNotFoundError: No module named 'spark'
